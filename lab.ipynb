# %%
path = '주자어류.1-140권.저본중화서국1994.박성규 교.최종본.txt'

# utf-8 with BOM
with open(path, 'r', encoding='utf-8-sig') as f:
    content = f.read()

# %%
print(content[:100])
# Out:
# 일러두기:
#  1. 󰡔朱子語類󰡕(全8冊)(黎靖德 編, 王星賢 點校, 中華書局, 北京, 1994)를 중국에서 입력한 자료를 다운받아 󰏧󰏰 체제에 맞게 전환한 다음 깨지거나 잘못 전환된
